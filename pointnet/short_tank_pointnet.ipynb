# %%
# %load_ext autoreload
# %matplotlib inline
# %autoreload 2

# %%
import numpy as np
import matplotlib.pyplot as plt
import os
import sys

# %%
#sys.path.append("../..")
sys.path.append("..")

from WatChMaL.analysis.multi_plot_utils import multi_disp_learn_hist, multi_compute_roc, multi_plot_roc
from WatChMaL.analysis.comparison_utils import multi_get_masked_data, multi_collapse_test_output

#from testing.test_utils import load_test_output_pn

# %%
############# define plotting params #############
c = plt.rcParams['axes.prop_cycle'].by_key()['color']
label_dict = {"$\gamma$":0, "$e$":1, "$\mu$":2}
inverse_label_dict = {0:"$\gamma$", 1:"$e$", 2:"$\mu$"}

# %%
############# define run locations #############
resnet_locs = ['/home/jtindall/short_tank/short_tank_OD_veto/short_tank_run_1/outputs']

resnet_titles = ['ResNet']

pointnet_locs = ['/home/nprouse/WatChMaL/WatChMaL/outputs/2021-01-16/11-18-35/outputs',
                 '/home/nprouse/WatChMaL/WatChMaL/outputs/2021-01-18/13-40-07/outputs',
                 '/home/nprouse/WatChMaL/WatChMaL/outputs/2021-01-16/11-16-58/outputs',
                 '/home/nprouse/WatChMaL/WatChMaL/outputs/2021-01-18/13-40-04/outputs',
                 '/home/nprouse/WatChMaL/WatChMaL/outputs/2021-01-20/13-26-16/outputs',
                 '/home/nprouse/WatChMaL/WatChMaL/outputs/2021-01-20/13-18-21/outputs',
                 '/home/nprouse/WatChMaL/WatChMaL/outputs/2021-01-21/18-00-55/outputs',
                 '/home/nprouse/WatChMaL/WatChMaL/outputs/2021-01-21/18-02-55/outputs',
                 '/home/nprouse/WatChMaL/WatChMaL/outputs/2021-01-23/02-47-53/outputs',
                 '/home/nprouse/WatChMaL/WatChMaL/outputs/2021-01-23/02-48-19/outputs',
                 '/home/nprouse/WatChMaL/WatChMaL/outputs/2021-01-27/17-21-34/outputs',
                 '/home/nprouse/WatChMaL/WatChMaL/outputs/2021-01-27/17-20-28/outputs']

pointnet_titles = ['PointNet bs128',
                   'PointNet bs128',
                   'PointNet+aug. bs128',
                   'PointNet+aug. bs128',
                   'PointNet+aug. bs256',
                   'PointNet+aug. bs256',
                   'PointNet+aug. bs256 maxpool',
                   'PointNet+aug. bs256 lr1e-3',
                   'PointNet+aug. bs256 lr1e-3',
                   'PointNet+aug. bs256 lr1e-2',
                   'PointNet mPMT 256 bs512',
                   'PointNet mPMT 512 bs512']

resnet_linecolor = [c[0]]
resnet_linestyle = ['-']

pointnet_linecolor = [c[1], c[1], c[1], c[1], c[2], c[2], c[1], c[1], c[1], c[4], c[2], c[2]]
pointnet_linestyle = [':',  ':',  ':',  ':',  '--',  '--',  ':',  ':', ':', '-.', '--', '-.']

# %%
fig = multi_disp_learn_hist(resnet_locs, losslim=2.5, titles=resnet_titles, leg_font=15, title_font=15, xmax=20)
# Out:
# i:  0
# Found training logs:  ['/home/jtindall/short_tank/short_tank_OD_veto/short_tank_run_1/outputs/log_train_0.csv']

# %%
fig = multi_disp_learn_hist(pointnet_locs[:2], losslim=2.5, titles=pointnet_titles[:2], leg_font=15, title_font=15, xmax=20)
# Out:
# i:  0
# Found training logs:  ['/home/nprouse/WatChMaL/WatChMaL/outputs/2021-01-16/11-18-35/outputs/log_train_1.csv', '/home/nprouse/WatChMaL/WatChMaL/outputs/2021-01-16/11-18-35/outputs/log_train_0.csv']
# i:  1
# Found training logs:  ['/home/nprouse/WatChMaL/WatChMaL/outputs/2021-01-18/13-40-07/outputs/log_train_0.csv']

# %%
fig = multi_disp_learn_hist(pointnet_locs[2:4], losslim=2.5, titles=pointnet_titles[2:4], leg_font=15, title_font=15, xmax=20)
# Out:
# i:  0
# Found training logs:  ['/home/nprouse/WatChMaL/WatChMaL/outputs/2021-01-16/11-16-58/outputs/log_train_1.csv', '/home/nprouse/WatChMaL/WatChMaL/outputs/2021-01-16/11-16-58/outputs/log_train_0.csv']
# i:  1
# Found training logs:  ['/home/nprouse/WatChMaL/WatChMaL/outputs/2021-01-18/13-40-04/outputs/log_train_0.csv']

# %%
fig = multi_disp_learn_hist(pointnet_locs[4:6], losslim=2.5, titles=pointnet_titles[4:6], leg_font=15, title_font=15, xmax=20)
# Out:
# i:  0
# Found training logs:  ['/home/nprouse/WatChMaL/WatChMaL/outputs/2021-01-20/13-26-16/outputs/log_train_1.csv', '/home/nprouse/WatChMaL/WatChMaL/outputs/2021-01-20/13-26-16/outputs/log_train_0.csv']
# i:  1
# Found training logs:  ['/home/nprouse/WatChMaL/WatChMaL/outputs/2021-01-20/13-18-21/outputs/log_train_1.csv', '/home/nprouse/WatChMaL/WatChMaL/outputs/2021-01-20/13-18-21/outputs/log_train_0.csv']

# %%
fig = multi_disp_learn_hist(pointnet_locs[6:8], losslim=2.5, titles=pointnet_titles[6:8], leg_font=15, title_font=15, xmax=20)
# Out:
# i:  0
# Found training logs:  ['/home/nprouse/WatChMaL/WatChMaL/outputs/2021-01-21/18-00-55/outputs/log_train_1.csv', '/home/nprouse/WatChMaL/WatChMaL/outputs/2021-01-21/18-00-55/outputs/log_train_0.csv']
# i:  1
# Found training logs:  ['/home/nprouse/WatChMaL/WatChMaL/outputs/2021-01-21/18-02-55/outputs/log_train_1.csv', '/home/nprouse/WatChMaL/WatChMaL/outputs/2021-01-21/18-02-55/outputs/log_train_0.csv']

# %%
fig = multi_disp_learn_hist(pointnet_locs[8:10], losslim=2.5, titles=pointnet_titles[8:10], leg_font=15, title_font=15, xmax=20)
# Out:
# i:  0
# Found training logs:  ['/home/nprouse/WatChMaL/WatChMaL/outputs/2021-01-23/02-47-53/outputs/log_train_1.csv', '/home/nprouse/WatChMaL/WatChMaL/outputs/2021-01-23/02-47-53/outputs/log_train_0.csv']
# i:  1
# Found training logs:  ['/home/nprouse/WatChMaL/WatChMaL/outputs/2021-01-23/02-48-19/outputs/log_train_1.csv', '/home/nprouse/WatChMaL/WatChMaL/outputs/2021-01-23/02-48-19/outputs/log_train_0.csv']

# %%
fig = multi_disp_learn_hist(pointnet_locs[10:12], losslim=2.5, titles=pointnet_titles[10:12], leg_font=15, title_font=15, xmax=20)
# Out:
# i:  0
# Found training logs:  ['/home/nprouse/WatChMaL/WatChMaL/outputs/2021-01-27/17-21-34/outputs/log_train_0.csv']
# i:  1
# Found training logs:  ['/home/nprouse/WatChMaL/WatChMaL/outputs/2021-01-27/17-20-28/outputs/log_train_0.csv']

# %%
locs = [resnet_locs[0], pointnet_locs[8]] #resnet_locs + pointnet_locs[7:9]+pointnet_locs[10:]
titles = ["ResNet", "PointNet"] #resnet_titles + pointnet_titles[7:9]+pointnet_titles[10:]
linecolor = [c[0], c[1]] #resnet_linecolor + pointnet_linecolor[7:9]+pointnet_linecolor[10:]
linestyle = ['-','--']#resnet_linestyle + pointnet_linestyle[7:9]+pointnet_linestyle[10:]

# %%
############# load short tank run data #############
short_idx_file_path = '/fast_scratch/WatChMaL/data/IWCD_mPMT_Short_3M_OD_veto_idxs.npz'
short_indices = np.load(short_idx_file_path)['test_idxs']

short_raw_output_softmax    = [np.load(loc + "/softmax.npy") for loc in locs]
short_raw_actual_labels    = [np.load(loc + "/labels.npy") for loc in locs]

# %%
############# compute short tank multi e/gamma ROC #############
fprs, tprs, thrs = multi_compute_roc(short_raw_output_softmax, short_raw_actual_labels,
                                     true_label=label_dict["$e$"], 
                                     false_label=label_dict["$\gamma$"])

# %%
figs = multi_plot_roc(fprs, tprs, thrs, "$e$", "$\gamma$", 
                      fig_list=[1], ylims=[[1,3e6]], 
                      linestyles=linestyle,linecolors=linecolor, 
                      plot_labels=titles, show=False)
# Out:
# [<AxesSubplot:>]
# [<AxesSubplot:title={'center':'$e$ vs $\\gamma$ Rejection'}, xlabel='$e$ Signal Efficiency', ylabel='$\\gamma$ Background Rejection'>]

# %%
figs = multi_plot_roc(fprs, tprs, thrs, "$e$", "$\gamma$", 
                      fig_list=[1], xlims=[[0.6,1.0]], ylims=[[1,4]],
                      linestyles=linestyle,linecolors=linecolor, 
                      plot_labels=titles, show=False)#,
                      #leg_loc='lower left')
# Out:
# [<AxesSubplot:>]
# [<AxesSubplot:title={'center':'$e$ vs $\\gamma$ Rejection'}, xlabel='$e$ Signal Efficiency', ylabel='$\\gamma$ Background Rejection'>]

# %%
muon_softmax_index_dict = {"e/gamma":0, "mu":1}

# %%
############# compute short collapsed ROC #############
short_collapsed_class_scores_list, short_collapsed_class_labels_list = multi_collapse_test_output(short_raw_output_softmax, short_raw_actual_labels, label_dict, ignore_type='$\gamma$')

short_collapsed_class_labels_list = [collapsed_class_labels - 1 for collapsed_class_labels in short_collapsed_class_labels_list]
short_collapsed_class_scores_list = [collapsed_class_scores[:,1:] for collapsed_class_scores in short_collapsed_class_scores_list]

# %%
fpr_list, tpr_list, thr_list = multi_compute_roc(short_collapsed_class_scores_list, short_collapsed_class_labels_list, 
                            true_label=muon_softmax_index_dict["e/gamma"], 
                            false_label=muon_softmax_index_dict["mu"])

# %%
figs = multi_plot_roc(fpr_list, tpr_list, thr_list,"e/gamma", "mu", 
                      fig_list=[1], ylims=[[1,1e6]], xlims=[[0.0,1.0]],
                      linestyles=linestyle,linecolors=linecolor, plot_labels=titles, show=False)#,
                      #leg_loc='lower left')
# Out:
# [<AxesSubplot:>]
# [<AxesSubplot:title={'center':'e/gamma vs mu Rejection'}, xlabel='e/gamma Signal Efficiency', ylabel='mu Background Rejection'>]

# %%
figs = multi_plot_roc(fpr_list, tpr_list, thr_list,"e/gamma", "mu", 
                      fig_list=[1], ylims=[[1,1e4]], xlims=[[0.9,1.0]],
                      linestyles=linestyle,linecolors=linecolor, plot_labels=titles, show=False)#,
                      #leg_loc='lower left')
# Out:
# [<AxesSubplot:>]
# [<AxesSubplot:title={'center':'e/gamma vs mu Rejection'}, xlabel='e/gamma Signal Efficiency', ylabel='mu Background Rejection'>]
