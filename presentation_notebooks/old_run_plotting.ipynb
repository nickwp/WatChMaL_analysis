# %%
# %load_ext autoreload
# %matplotlib inline
# %autoreload 2

# %%
import numpy as np
import matplotlib.pyplot as plt
import os
import sys

# %%
#sys.path.append("../..")
sys.path.append("..")

from WatChMaL.analysis.multi_plot_utils import multi_disp_learn_hist, multi_compute_roc, multi_plot_roc
from WatChMaL.analysis.comparison_utils import multi_get_masked_data, multi_collapse_test_output

# %%
############# define plotting params #############
c = plt.rcParams['axes.prop_cycle'].by_key()['color']
label_dict = {"$\gamma$":0, "$e$":1, "$\mu$":2}
inverse_label_dict = {0:"$\gamma$", 1:"$e$", 2:"$\mu$"}

# %%
path_1 = ['/home/jtindall/presentation_links/20200724_164640_nomichel_3class']
title_1 = ['Previous Run']

# %%
fig = multi_disp_learn_hist(path_1, losslim=2.5, titles=title_1, leg_font=15, title_font=15, xmax=20)
# Out:
# i:  0
# Found training logs:  ['/home/jtindall/presentation_links/20200724_164640_nomichel_3class/log_train_0.csv']

# %%
path_2 = ['/home/jtindall/presentation_links/20200730_151851_barrel_fix_only_3class']
title_2 = ['No Transformed Data']

# %%
fig = multi_disp_learn_hist(path_2, losslim=1.6, titles=title_2, leg_font=15, title_font=15, xmax=20)
# Out:
# i:  0
# Found training logs:  ['/home/jtindall/presentation_links/20200730_151851_barrel_fix_only_3class/log_train_0.csv']

# %%
path_3 = ['/home/jtindall/presentation_links/20200729_125923_transforms_3class_rerun']
title_3 = ['Including Transformed Data']

# %%
fig = multi_disp_learn_hist(path_3, losslim=1.6, titles=title_3, leg_font=15, title_font=15, xmax=20)
# Out:
# i:  0
# Found training logs:  ['/home/jtindall/presentation_links/20200729_125923_transforms_3class_rerun/log_train_0.csv']
