# %%
# %load_ext autoreload
# %matplotlib inline
# %autoreload 2

# %%
import sys
import glob
import os
import h5py
import numpy as np
import matplotlib.pyplot as plt

# %%
print(os.getcwd())
sys.path.append('/home/jtindall/WatChMaL_analysis/')
sys.path.append('/home/jtindall/WatChMaL_analysis/WatChMaL')
# Out:
# /home/jtindall/WatChMaL_analysis/gan_notebooks

# %%
from WatChMaL.analysis.event_analysis.GANEventPlotter import GANEventPlotter

# %%
plotter = GANEventPlotter(h5_path='/fast_scratch/WatChMaL/data/IWCD_mPMT_Short_emg_E0to1000MeV_digihits.h5',
                       mpmt_positions_file='/data/WatChMaL/data/IWCDshort_mPMT_image_positions.npz', 
                       geo_path='/fast_scratch/WatChMaL/data/geo_mPMTshort.npz')

# %%
path = '/home/jtindall/WatChMaL/outputs/2021-01-09/gan_full_1/outputs'

# %%
image_batches = [np.load(fname,allow_pickle=True)['gen_imgs'] for fname in glob.glob(os.path.join(path,'imgs/*'))]
print(len(image_batches))

test_batch = image_batches[-1]
print(test_batch.shape)

test_image = test_batch[3]
print(test_image.shape)
# Out:
# 108
# (64, 19, 40, 40)
# (19, 40, 40)

# %%
gan_image_pmts, gan_image_data = plotter.reconstruct_gan_data(test_image)

# %%
plotter.display_data(gan_image_pmts, gan_image_data)

# %%
plotter.display_gan_image(test_image)
# Out:
# ------------------------------------------------------------------------
# AttributeError                         Traceback (most recent call last)
# <ipython-input-41-b142f42dab13> in <module>
# ----> 1 plotter.display_gan_image(test_image)
#
# ~/WatChMaL_analysis/WatChMaL/analysis/event_analysis/GANEventPlotter.py in display_gan_image(self, image_data, ax)
#      27     def display_gan_image(self, image_data, ax=None):
#      28         hit_pmts, hit_data = self.reconstruct_gan_data(image_data)
# ---> 29         return self.plot_data(hit_pmts, hit_data, cutrange=[-1,1], ax=ax)
#      30
#      31     def load_image_batches(self, path):
#
# ~/WatChMaL_analysis/WatChMaL/analysis/event_analysis/EventPlotter.py in plot_data(self, tubes, quantities, cutrange, ax)
#     158             imgmax = cutrange[1]
#     159
# ...

# %%
# Test displaying batch
fig, axes = plt.subplots(16, 4, figsize=(25, 50), facecolor='w')
plotter.display_batch(test_batch, axes=axes)
plt.show()
# Out:
# (64, 19, 40, 40)
# (64, 19, 40, 40)
# (64, 19, 40, 40)
# (64, 19, 40, 40)
# (64, 19, 40, 40)
# (64, 19, 40, 40)
# (64, 19, 40, 40)
# (64, 19, 40, 40)
# (64, 19, 40, 40)
# (64, 19, 40, 40)
